# %%
# set the environment variables needed for openai package to know to reach out to azure
import os

os.environ["OPENAI_API_TYPE"] = "azure"
os.environ["OPENAI_API_BASE"] = "https://<your-endpoint.openai.azure.com/"
os.environ["OPENAI_API_KEY"] = "your AzureOpenAI key"
os.environ["OPENAI_API_VERSION"] = "2023-05-15"

from langchain.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(deployment="text-embedding-ada-002")

text = "This is a test document."

# %%
query_result = embeddings.embed_query(text)
# Out:
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIConnectionError: Error communicating with OpenAI: HTTPSConnectionPool(host='%3cyour-endpoint.openai.azure.com', port=443): Max retries exceeded with url: //openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-05-15 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000026A5A0FE4D0>: Failed to resolve '%3cyour-endpoint.openai.azure.com' ([Errno 11001] getaddrinfo failed)")).
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIConnectionError: Error communicating with OpenAI: HTTPSConnectionPool(host='%3cyour-endpoint.openai.azure.com', port=443): Max retries exceeded with url: //openai/deployments/text-embedding-ada-002/embeddings?api-version=2023-05-15 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000026A5A10C220>: Failed to resolve '%3cyour-endpoint.openai.azure.com' ([Errno 11001] getaddrinfo failed)")).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Repos\langchain notebook\models\integrations\azure-openai-embedings.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Repos/langchain%20notebook/models/integrations/azure-openai-embedings.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> query_result = embeddings.embed_query(text)
#
# File c:\Repos\langchain notebook\.conda\lib\site-packages\langchain\embeddings\openai.py:506, in OpenAIEmbeddings.embed_query(self, text)
#     497 def embed_query(self, text: str) -> List[float]:
#     498     """Call out to OpenAI's embedding endpoint for embedding query text.
#     499
#     500     Args:
#    (...)
#     504         Embedding for the text.
#     505     """
# --> 506     return self.embed_documents([text])[0]
#
# File c:\Repos\langchain notebook\.conda\lib\site-packages\langchain\embeddings\openai.py:478, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     466 """Call out to OpenAI's embedding endpoint for embedding search docs.
#     467
#     468 Args:
#    (...)
#     474     List of embeddings, one for each text.
#     475 """
#     476 # NOTE: to keep things simple, we assume the list may contain texts longer
#     477 #       than the maximum context and use length-safe embedding function.
# --> 478 return self._get_len_safe_embeddings(texts, engine=self.deployment)
#
# File c:\Repos\langchain notebook\.conda\lib\site-packages\langchain\embeddings\openai.py:364, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     361     _iter = range(0, len(tokens), _chunk_size)
#     363 for i in _iter:
# --> 364     response = embed_with_retry(
#     365         self,
#     366         input=tokens[i : i + _chunk_size],
#     367         **self._invocation_params,
#     368     )
#     369     batched_embeddings.extend(r["embedding"] for r in response["data"])
#     371 results: List[List[List[float]]] = [[] for _ in range(len(texts))]
#
# File c:\Repos\langchain notebook\.conda\lib\site-packages\langchain\embeddings\openai.py:107, in embed_with_retry(embeddings, **kwargs)
#     104     response = embeddings.client.create(**kwargs)
#     105     return _check_response(response)
# --> 107 return _embed_with_retry(**kwargs)
#
# File c:\Repos\langchain notebook\.conda\lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File c:\Repos\langchain notebook\.conda\lib\site-packages\tenacity\__init__.py:389, in Retrying.__call__(self, fn, *args, **kwargs)
#     387 elif isinstance(do, DoSleep):
#     388     retry_state.prepare_for_next_attempt()
# --> 389     self.sleep(do)
#     390 else:
#     391     return do
#
# File c:\Repos\langchain notebook\.conda\lib\site-packages\tenacity\nap.py:31, in sleep(seconds)
#      25 def sleep(seconds: float) -> None:
#      26     """
#      27     Sleep strategy that delays execution for a given number of seconds.
#      28
#      29     This is the default strategy, and may be mocked out for unit testing.
#      30     """
# ---> 31     time.sleep(seconds)
#
# KeyboardInterrupt:

# %%
doc_result = embeddings.embed_documents([text])

# %%
print(query_result)
# Out:
# [-0.003158408751234257, 0.011094410212838681, -0.004001317166816524, -0.011747414500761144, -0.0010153218392504925, 0.010781234363886397, -0.010368109905383125, -0.005297331254235388, -0.009881687564701569, -0.02616015319589311, 0.020376399600976168, 0.02257529322548534, -0.007522876537439856, 0.017284624653093127, -0.006003641653516228, 0.019123698067812216, 0.021255957423308873, -0.015645450320121202, 0.007669469042167343, -0.018364081557172996, -0.0006909018997805781, -0.006416767043342095, -0.010